# %%
import numpy as np
import pandas as pd
import scipy

# %%
x = 5
y = 6
print(x+y)

my_string = "Python"
print(my_string)
# Out:
# 11
# Python

# %%
len(my_string)
# Out:
# 6

# %%
print("my " + my_string + " is level " + str(x))
# Out:
# my Python is level 5

# %%
my_string[0], my_string[2], my_string[0:2], my_string[-1::-2]
# Out:
# ('P', 't', 'Py', 'nhy')

# %%
my_string.upper(), my_string.replace("y", "yy"), my_string.find("y")
# Out:
# ('PYTHON', 'Pyython', 1)

# %%
colors = ["red","blue","green"]
print(colors[0])
colors.append("yellow")
print(colors)
colors.insert(1, "pink")  # insert at any position
print(colors)
colors.pop(1)      # remove an element
print(colors)
print(colors.index("green"))   # search for an element
# Out:
# red
# ['red', 'blue', 'green', 'yellow']
# ['red', 'pink', 'blue', 'green', 'yellow']
# ['red', 'blue', 'green', 'yellow']
# 2

# %%
x = 10
if x == 5:
    print("'Y'")
else:
    print("N")
# Out:
# N

# %%
a = [2,3,5,7]
for element in a:
    print(a)
# Out:
# [2, 3, 5, 7]
# [2, 3, 5, 7]
# [2, 3, 5, 7]
# [2, 3, 5, 7]

# %%
my_tuple =("price", 5.7)
print(len(my_tuple))
print(my_tuple[1])
# Out:
# 2
# 5.7

# %%
# numpy arrany

my_array = np.array([1,2,3,4])
print(len(my_array))
my_array[my_array>2]
# Out:
# 4
# array([3, 4])

# %%
my_array.sum(),my_array.max(), my_array.mean()   #aggregation
# Out:
# (10, 4, 2.5)

# %%
my_array=np.array([1,2,2,4,5])   # remove duplicate
np.unique(my_array)
# Out:
# array([1, 2, 4, 5])

# %%
np.append(my_array,6), np.insert(my_array,3,3), np.delete(my_array,[1])  # add/remove
# Out:
# (array([1, 2, 2, 4, 5, 6]), array([1, 2, 2, 3, 4, 5]), array([1, 2, 4, 5]))

# %%
# Panda dataframe

# %%
df = pd.DataFrame(
    {
        "cust_id" : ["A","B","C"],
        "date": ["5/1/2017", "5/8/2017","5/22/2017"],
        "spend": [10,5,20]
        
    },
    # index
    columns = ["cust_id", "date", "spend"]
)

#describe table
df.shape
# Out:
# (3, 3)

# %%
# subset columns
df["spend"]   # an array
# Out:
# 0    10
# 1     5
# 2    20
# Name: spend, dtype: int64

# %%
df[["spend"]]  # a dataframe
# Out:
#    spend
# 0     10
# 1      5
# 2     20

# %%
df[["cust_id","spend"]]
# Out:
#   cust_id  spend
# 0       A     10
# 1       B      5
# 2       C     20

# %%
# subset rows
df.sample(n=1)    # random
# Out:
#   cust_id      date  spend
# 0       A  5/1/2017     10

# %%
df.head(n=3)
# Out:
#   cust_id       date  spend
# 0       A   5/1/2017     10
# 1       B   5/8/2017      5
# 2       C  5/22/2017     20

# %%
# pandas data I/O

# %%
# from csv  "C:\Users\grace\Downloads\BA501_python_data.csv"
file_location = "/Users/grace//Downloads/"
file_name = "BA501_python_data.csv"
my_data = pd.read_csv(file_location + file_name)

my_data.head(10)
# Out:
#   country      date  experiment_id              order_id  spend_usd  \
# 0      JP  20170402       12624548   5813140433216629693  16.138855
# 1      US  20170403       12624549  16333056276711034931   9.990000
# 2      JP  20170404       12624548  11227119161741298366  19.887087
# 3      US  20170403       12624548  11927299833124210932  19.990000
# 4      JP  20170403       12624549  11644727017708872749  88.220093
# 5      FR  20170406       12624548   2887851716418524034  10.641677
# 6      US  20170406       12624548   8835194413765780524   9.990000
# 7      US  20170402       12624549   2761291987218019434  10.090000
# 8      US  20170405       12624548   9027895522629963459   9.990000
# 9      US  20170405       12624548   2588200289165850850  19.990000
#
#                 user_id      vertical
# 0   5006730028073359543  ANDROID_APPS
# 1   5938685669571545259  ANDROID_APPS
# 2  17623708458399141713  ANDROID_APPS
# 3  18042812344456618148  ANDROID_APPS
# ...

# %%
my_data[(my_data.country == "JP")].head(5)  # selsect column
# Out:
#    country      date  experiment_id              order_id  spend_usd  \
# 0       JP  20170402       12624548   5813140433216629693  16.138855
# 2       JP  20170404       12624548  11227119161741298366  19.887087
# 4       JP  20170403       12624549  11644727017708872749  88.220093
# 12      JP  20170402       12624549   1931426249776431110   5.379618
# 41      JP  20170401       12624549   7104670035152263784   5.379618
#
#                  user_id      vertical
# 0    5006730028073359543  ANDROID_APPS
# 2   17623708458399141713  ANDROID_APPS
# 4    4325104700699531031  ANDROID_APPS
# 12   1925282073030462007  ANDROID_APPS
# 41  13151664051368694565  ANDROID_APPS

# %%
my_data[["user_id","date","spend_usd"]].head(5)
# Out:
#                 user_id      date  spend_usd
# 0   5006730028073359543  20170402  16.138855
# 1   5938685669571545259  20170403   9.990000
# 2  17623708458399141713  20170404  19.887087
# 3  18042812344456618148  20170403  19.990000
# 4   4325104700699531031  20170403  88.220093

# %%
my_data["user_id"].head(5)
# Out:
# 0     5006730028073359543
# 1     5938685669571545259
# 2    17623708458399141713
# 3    18042812344456618148
# 4     4325104700699531031
# Name: user_id, dtype: uint64

# %%
my_data["country"]
# Out:
# 15381     AE
# 22250     AE
# 19088     AE
# 38119     AE
# 22092     AE
# 17146     AR
# 68222     AR
# 68224     AR
# 17147     AR
# 49877     AR
# 68220     AR
# 68221     AR
# 49876     AR
# 49878     AR
# 68223     AR
# 1163      AT
# 1888      AT
# 2834      AT
# 4682      AT
# 4684      AT
# 5645      AT
# 7642      AT
# 7643      AT
# 7645      AT
# 7646      AT
# 8206      AT
# 8868      AT
# 8869      AT
# 9780      AT
# 9781      AT
#         ...
# 49082     ZA
# 50034     ZA
# 52916     ZA
# 53978     ZA
# 54709     ZA
# 54950     ZA
# 57628     ZA
# 63575     ZA
# 66107     ZA
# 68793     ZA
# 68796     ZA
# 68799     ZA
# 68804     ZA
# 68811     ZA
# 69308     ZA
# 69758     ZA
# 72633     ZA
# 72634     ZA
# 32917    NaN
# 32922    NaN
# 32925    NaN
# 32918    NaN
# 32923    NaN
# 32916    NaN
# 32919    NaN
# 32920    NaN
# 32921    NaN
# 32926    NaN
# 32915    NaN
# 32924    NaN
# Name: country, Length: 73910, dtype: object

# %%
my_data[1:10]  # select rows
# Out:
#   country      date  experiment_id              order_id  spend_usd  \
# 1      US  20170403       12624549  16333056276711034931   9.990000
# 2      JP  20170404       12624548  11227119161741298366  19.887087
# 3      US  20170403       12624548  11927299833124210932  19.990000
# 4      JP  20170403       12624549  11644727017708872749  88.220093
# 5      FR  20170406       12624548   2887851716418524034  10.641677
# 6      US  20170406       12624548   8835194413765780524   9.990000
# 7      US  20170402       12624549   2761291987218019434  10.090000
# 8      US  20170405       12624548   9027895522629963459   9.990000
# 9      US  20170405       12624548   2588200289165850850  19.990000
#
#                 user_id      vertical
# 1   5938685669571545259  ANDROID_APPS
# 2  17623708458399141713  ANDROID_APPS
# 3  18042812344456618148  ANDROID_APPS
# 4   4325104700699531031  ANDROID_APPS
# 5  15563614621402392174  ANDROID_APPS
# 6    793284520969747371  ANDROID_APPS
# ...

# %%
my_data[(my_data.user_id == 7250841187939126009) & (my_data.country == "JP")]
# Out:
# Empty DataFrame
# Columns: [country, date, experiment_id, order_id, spend_usd, user_id, vertical]
# Index: []

# %%
my_data[["user_id","date","spend_usd"]][(my_data.user_id == 7250841187939126009) & (my_data.country == "JP")]
# Out:
# Empty DataFrame
# Columns: [user_id, date, spend_usd]
# Index: []

# %%
# create new columns
my_data["spend_usd_whole"] = my_data["spend_usd"]*5
my_data.head(5)
# Out:
#   country      date  experiment_id              order_id  spend_usd  \
# 0      JP  20170402       12624548   5813140433216629693  16.138855
# 1      US  20170403       12624549  16333056276711034931   9.990000
# 2      JP  20170404       12624548  11227119161741298366  19.887087
# 3      US  20170403       12624548  11927299833124210932  19.990000
# 4      JP  20170403       12624549  11644727017708872749  88.220093
#
#                 user_id      vertical  spend_usd_whole
# 0   5006730028073359543  ANDROID_APPS        80.694275
# 1   5938685669571545259  ANDROID_APPS        49.950000
# 2  17623708458399141713  ANDROID_APPS        99.435435
# 3  18042812344456618148  ANDROID_APPS        99.950000
# 4   4325104700699531031  ANDROID_APPS       441.100465

# %%
# drop column
my_data = my_data.drop("spend_usd_whole", axis = 1)
my_data.head(5)
# Out:
#   country      date  experiment_id              order_id  spend_usd  \
# 0      JP  20170402       12624548   5813140433216629693  16.138855
# 1      US  20170403       12624549  16333056276711034931   9.990000
# 2      JP  20170404       12624548  11227119161741298366  19.887087
# 3      US  20170403       12624548  11927299833124210932  19.990000
# 4      JP  20170403       12624549  11644727017708872749  88.220093
#
#                 user_id      vertical
# 0   5006730028073359543  ANDROID_APPS
# 1   5938685669571545259  ANDROID_APPS
# 2  17623708458399141713  ANDROID_APPS
# 3  18042812344456618148  ANDROID_APPS
# 4   4325104700699531031  ANDROID_APPS

# %%
# change data type, date into date format
my_data.date = pd.to_datetime(my_data.date, format='%Y%m%d')
my_data.head(4)
# Out:
#       country       date  experiment_id              order_id  spend_usd  \
# 15381      AE 2017-04-03       12624548   8078410735682954089   1.984784
# 22250      AE 2017-04-04       12624549   6754390085836948239   0.977429
# 19088      AE 2017-04-05       12624549  13528583286475944786  10.071074
# 38119      AE 2017-04-05       12624548  18081415353723908788   0.952926
#
#                     user_id      vertical
# 15381  15342218896746506117  ANDROID_APPS
# 22250  11276568206142884528  ANDROID_APPS
# 19088  10187980296635197684  ANDROID_APPS
# 38119    921275339006250633  ANDROID_APPS

# %%
# groupby(), select country, sum(spend_usd) from a group by 1, and rest the index
result = my_data.groupby(["country"])["spend_usd"].sum().reset_index()
result
# Out:
#    country      spend_usd
# 0       AE      14.963641
# 1       AR      16.180000
# 2       AT    3759.115467
# 3       AU   15877.633679
# 4       BE    2789.523098
# 5       BR    7226.139306
# 6       CA   12951.332762
# 7       CH    3549.431644
# 8       CZ       4.982100
# 9       DE   31491.686018
# 10      DK    1358.179783
# 11      DZ       1.990000
# 12      EG       1.432207
# 13      ES    6280.247879
# 14      FI    1458.194388
# 15      FR   21180.562013
# 16      GB   22644.965632
# 17      GR     803.236874
# 18      HK   10188.606958
# 19      HR       1.290010
# 20      HU      15.460824
# 21      ID    5480.962275
# 22      IE    1160.637553
# 23      IL      12.082609
# 24      IN    2393.356750
# 25      IS       2.490535
# 26      IT    9360.671022
# 27      JP  241406.864175
# 28      KR  131706.979622
# 29      KW      12.960000
# 30      LV       2.111318
# 31      MX      52.039831
# 32      MY       8.604777
# 33      NL    4226.217002
# ...

# %%
# order by: sort values()
my_data = my_data.sort_values(['country','date'],ascending=[True, True])
my_data.head(5)
# Out:
#       country      date  experiment_id              order_id  spend_usd  \
# 15381      AE  20170403       12624548   8078410735682954089   1.984784
# 22250      AE  20170404       12624549   6754390085836948239   0.977429
# 19088      AE  20170405       12624549  13528583286475944786  10.071074
# 38119      AE  20170405       12624548  18081415353723908788   0.952926
# 22092      AE  20170407       12624549  18156435304744752611   0.977428
#
#                     user_id      vertical
# 15381  15342218896746506117  ANDROID_APPS
# 22250  11276568206142884528  ANDROID_APPS
# 19088  10187980296635197684  ANDROID_APPS
# 38119    921275339006250633  ANDROID_APPS
# 22092   5956003464692123193  ANDROID_APPS

# %%
# Join: merge()
# pd.merge(left_table, right_table,how='left',on='x1','x2')

# Union: concat()--left/right combine, stack()--like Union all, more important!!
# pd.concat([left_table, right_table])
# pd.stack([upper_table, lower_table])
